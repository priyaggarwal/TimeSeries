# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ren_data = pd.read_csv("renewables_data.cleaned.csv")
ren_data
# Out:
#        Unnamed: 0  Hour  Geothermal  Biomass  Biogas  Small Hydro  Wind  \
# 0               0     1        1056      323     170          250   632
# 1               1     2        1055      318     169          245   632
# 2               2     3        1058      316     168          240   677
# 3               3     4        1063      318     168          238   923
# 4               4     5        1066      318     168          247   875
# 5               5     6        1066      317     169          247   998
# 6               6     7        1066      312     166          244   763
# 7               7     8        1067      313     167          269   544
# 8               8     9        1065      315     169          280   572
# 9               9    10        1063      316     167          294   721
# 10             10    11        1063      314     169          294   658
# 11             11    12        1066      317     171          271   772
# ...

# %%
ren_data = ren_data.drop('Unnamed: 0', axis=1)
ren_data
# Out:
#        Hour  Geothermal  Biomass  Biogas  Small Hydro  Wind  Solar  \
# 0         1        1056      323     170          250   632    0.0
# 1         2        1055      318     169          245   632    0.0
# 2         3        1058      316     168          240   677    0.0
# 3         4        1063      318     168          238   923    0.0
# 4         5        1066      318     168          247   875    0.0
# 5         6        1066      317     169          247   998    0.0
# 6         7        1066      312     166          244   763    0.0
# 7         8        1067      313     167          269   544    1.0
# 8         9        1065      315     169          280   572  191.0
# 9        10        1063      316     167          294   721  299.0
# 10       11        1063      314     169          294   658  278.0
# 11       12        1066      317     171          271   772  198.0
# 12       13        1068      324     171          270  1012  126.0
# ...

# %%
print(type(ren_data.iloc[0]['Geothermal']))
print(type(ren_data.iloc[0]['Biomass']))
print(type(ren_data.iloc[0]['Biogas']))
print(type(ren_data.iloc[0]['Small Hydro']))
print(type(ren_data.iloc[0]['Wind']))
print(type(ren_data.iloc[0]['Solar']))
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>

# %%
ren_data.plot(x='Date', y='Geothermal', title='Geothermal Data', style='o')

# %%
ren_data.plot(x='Date', y='Biomass', title='Biomass Data', style='o')

# %%
ren_data.plot(x='Date', y='Biogas', title='Biogas Data', style = 'o')

# %%
ren_data.plot(x='Date', y='Small Hydro', title='Small Hydro', style='o')

# %%
ren_data.plot(x='Date', y='Wind', title='Wind', style='o')

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf
# Out:
# /Users/omkarshanbhag/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
